# %%
# # def ALL_Page_Info():
    
# import requests     # Importing request Library.

# from bs4 import BeautifulSoup    # Import BeautifulSoup from above.

# import re   # Importing Regular Expression.

# url = 'https://www.themoviedb.org'   # This is  outer Link.

# header = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.51 Safari/537.36'}

# all_page_urls = []   # Taking a empty list.

# for i in range(1,26):   # Using for loop For Fetching URLS .

#     num = str(i)    # Taking num Variable For Store i in String.

#     all_response_data = requests.get(url+'/movie?page='+num, headers = header).text # Get the all_Response_data from the URL website.

#     all_soup_data = BeautifulSoup(all_response_data) # Using BeautifulSoup to parse the all_Response_data.

#     all_divs = all_soup_data.find_all('div',class_='card style_1') # Creating one varialble to store common base of box.

#     for item in all_divs:  # Using For Loop to Fetch All Data From all_divs.

#         name = item.find('h2')   # Fetching Movi_Name.
#         link = name.find('a')['href']
#         Movie_Name = item.find('h2').text
# #         print(Movie_Name)                                          # Print to Fetch name
#         Url = url + link
# #         print(Url)

#         inside_page_data = requests.get(Url,headers = header).text # This is Inner Link.
#         soupdata_of_insidepage = BeautifulSoup(inside_page_data,'lxml') # Using BeautifulSoup to parse the inside_page_data.


#         rating = soupdata_of_insidepage.find('div',class_='percent')
#         rating1 = rating.find('span')['class'][1].strip('icon-r')
# #         print(rating1)                                        # Print to Fetch rating.

#         genre = soupdata_of_insidepage.find('span',class_='genres').text.strip()
# #         print(genre)                                          # Print to Fetch genre.

#         release_date = soupdata_of_insidepage.find('span',class_='release').text.strip()
#         release_date1 = release_date[:-4]
# #         print(release_date1)                                  # Print to Fetch release_date1.

#         run_time = soupdata_of_insidepage.find('span',class_='runtime').text.strip()
# #         print(run_time)                                       # Print to Fetch run_time.

#         director_name = soupdata_of_insidepage.find('ol',class_='people no_image')
#         di = director_name.find_all('li',class_='profile')
#         for items in di:               # Using For Loop For Fetching Director Name.
#             a = items.find('p',class_='character').text
#             if a.count('Director') == 1:
#                 director_name = items.find('a').text
#                 print(director_name)                            # Print to Fetch director_name
#             else:
#                 print('No director_name')

#         all_page_info = {                       # Store all keys and values in one dictionary.
#             'Name': Movie_Name,
#             'Rating': rating1,
#             'Genre': genre,
#             'Release Date': release_date1,
#             'Run Time': run_time,
#             'Director': director_name,
#             'URL': Url
#         }

#         all_page_urls.append(all_page_info)    # Taking all_page_urls in empty list.
#         print(all_page_urls)                                          # Print to get all_page_urls.
# # ALL_Page_Info()
# Out:
# Terrifier 2
# Damien Leone
# [{'Name': 'Terrifier 2', 'Rating': '74', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/28/2022 ', 'Run Time': '2h 18m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/663712'}]
# Black Adam
# No director_name
# No director_name
# Jaume Collet-Serra
# No director_name
# No director_name
# No director_name
# [{'Name': 'Terrifier 2', 'Rating': '74', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/28/2022 ', 'Run Time': '2h 18m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/663712'}, {'Name': 'Black Adam', 'Rating': '70', 'Genre': 'Action,\xa0Fantasy,\xa0Science Fiction', 'Release Date': '10/21/2022 ', 'Run Time': '2h 5m', 'Director': 'Jaume Collet-Serra', 'URL': 'https://www.themoviedb.org/movie/436270'}]
# Jeepers Creepers: Reborn
# No director_name
# Timo Vuorensola
# [{'Name': 'Terrifier 2', 'Rating': '74', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/28/2022 ', 'Run Time': '2h 18m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/663712'}, {'Name': 'Black Adam', 'Rating': '70', 'Genre': 'Action,\xa0Fantasy,\xa0Science Fiction', 'Release Date': '10/21/2022 ', 'Run Time': '2h 5m', 'Director': 'Jaume Collet-Serra', 'URL': 'https://www.themoviedb.org/movie/436270'}, {'Name': 'Jeepers Creepers: Reborn', 'Rating': '58', 'Genre': 'Horror,\xa0Thriller,\xa0Mystery', 'Release Date': '09/15/2022 ', 'Run Time': '1h 28m', 'Director': 'Timo Vuorensola', 'URL': 'https://www.themoviedb.org/movie/717728'}]
# Fullmetal Alchemist: The Final Alchemy
# Fumihiko Sori
# No director_name
# [{'Name': 'Terrifier 2', 'Rating': '74', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/28/2022 ', 'Run Time': '2h 18m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/663712'}, {'Name': 'Black Adam', 'Rating': '70', 'Genre': 'Action,\xa0Fantasy,\xa0Science Fiction', 'Release Date': '10/21/2022 ', 'Run Time': '2h 5m', 'Director': 'Jaume Collet-Serra', 'URL': 'https://www.themoviedb.org/movie/436270'}, {'Name': 'Jeepers Creepers: Reborn', 'Rating': '58', 'Genre': 'Horror,\xa0Thriller,\xa0Mystery', 'Release Date': '09/15/2022 ', 'Run Time': '1h 28m', 'Director': 'Timo Vuorensola', 'URL': 'https://www.themoviedb.org/movie/717728'}, {'Name': 'Fullmetal Alchemist: The Final Alchemy', 'Rating': '62', 'Genre': 'Action,\xa0Adventure,\xa0Fantasy', 'Release Date': '06/24/2022 ', 'Run Time': '2h 23m', 'Director': 'Fumihiko Sori', 'URL': 'https://www.themoviedb.org/movie/960704'}]
# Orphan: First Kill
# No director_name
# William Brent Bell
# No director_name
# No director_name
# [{'Name': 'Terrifier 2', 'Rating': '74', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/28/2022 ', 'Run Time': '2h 18m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/663712'}, {'Name': 'Black Adam', 'Rating': '70', 'Genre': 'Action,\xa0Fantasy,\xa0Science Fiction', 'Release Date': '10/21/2022 ', 'Run Time': '2h 5m', 'Director': 'Jaume Collet-Serra', 'URL': 'https://www.themoviedb.org/movie/436270'}, {'Name': 'Jeepers Creepers: Reborn', 'Rating': '58', 'Genre': 'Horror,\xa0Thriller,\xa0Mystery', 'Release Date': '09/15/2022 ', 'Run Time': '1h 28m', 'Director': 'Timo Vuorensola', 'URL': 'https://www.themoviedb.org/movie/717728'}, {'Name': 'Fullmetal Alchemist: The Final Alchemy', 'Rating': '62', 'Genre': 'Action,\xa0Adventure,\xa0Fantasy', 'Release Date': '06/24/2022 ', 'Run Time': '2h 23m', 'Director': 'Fumihiko Sori', 'URL': 'https://www.themoviedb.org/movie/960704'}, {'Name': 'Orphan: First Kill', 'Rating': '68', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/17/2022 ', 'Run Time': '1h 39m', 'Director': 'William Brent Bell', 'URL': 'https://www.themoviedb.org/movie/760161'}]
# Hocus Pocus 2
# No director_name
# No director_name
# Anne Fletcher
# No director_name
# No director_name
# [{'Name': 'Terrifier 2', 'Rating': '74', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/28/2022 ', 'Run Time': '2h 18m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/663712'}, {'Name': 'Black Adam', 'Rating': '70', 'Genre': 'Action,\xa0Fantasy,\xa0Science Fiction', 'Release Date': '10/21/2022 ', 'Run Time': '2h 5m', 'Director': 'Jaume Collet-Serra', 'URL': 'https://www.themoviedb.org/movie/436270'}, {'Name': 'Jeepers Creepers: Reborn', 'Rating': '58', 'Genre': 'Horror,\xa0Thriller,\xa0Mystery', 'Release Date': '09/15/2022 ', 'Run Time': '1h 28m', 'Director': 'Timo Vuorensola', 'URL': 'https://www.themoviedb.org/movie/717728'}, {'Name': 'Fullmetal Alchemist: The Final Alchemy', 'Rating': '62', 'Genre': 'Action,\xa0Adventure,\xa0Fantasy', 'Release Date': '06/24/2022 ', 'Run Time': '2h 23m', 'Director': 'Fumihiko Sori', 'URL': 'https://www.themoviedb.org/movie/960704'}, {'Name': 'Orphan: First Kill', 'Rating': '68', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/17/2022 ', 'Run Time': '1h 39m', 'Director': 'William Brent Bell', 'URL': 'https://www.themoviedb.org/movie/760161'}, {'Name': 'Hocus Pocus 2', 'Rating': '76', 'Genre': 'Fantasy,\xa0Comedy,\xa0Family', 'Release Date': '09/30/2022 ', 'Run Time': '1h 47m', 'Director': 'Anne Fletcher', 'URL': 'https://www.themoviedb.org/movie/642885'}]
# Fall
# Scott Mann
# No director_name
# [{'Name': 'Terrifier 2', 'Rating': '74', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/28/2022 ', 'Run Time': '2h 18m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/663712'}, {'Name': 'Black Adam', 'Rating': '70', 'Genre': 'Action,\xa0Fantasy,\xa0Science Fiction', 'Release Date': '10/21/2022 ', 'Run Time': '2h 5m', 'Director': 'Jaume Collet-Serra', 'URL': 'https://www.themoviedb.org/movie/436270'}, {'Name': 'Jeepers Creepers: Reborn', 'Rating': '58', 'Genre': 'Horror,\xa0Thriller,\xa0Mystery', 'Release Date': '09/15/2022 ', 'Run Time': '1h 28m', 'Director': 'Timo Vuorensola', 'URL': 'https://www.themoviedb.org/movie/717728'}, {'Name': 'Fullmetal Alchemist: The Final Alchemy', 'Rating': '62', 'Genre': 'Action,\xa0Adventure,\xa0Fantasy', 'Release Date': '06/24/2022 ', 'Run Time': '2h 23m', 'Director': 'Fumihiko Sori', 'URL': 'https://www.themoviedb.org/movie/960704'}, {'Name': 'Orphan: First Kill', 'Rating': '68', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/17/2022 ', 'Run Time': '1h 39m', 'Director': 'William Brent Bell', 'URL': 'https://www.themoviedb.org/movie/760161'}, {'Name': 'Hocus Pocus 2', 'Rating': '76', 'Genre': 'Fantasy,\xa0Comedy,\xa0Family', 'Release Date': '09/30/2022 ', 'Run Time': '1h 47m', 'Director': 'Anne Fletcher', 'URL': 'https://www.themoviedb.org/movie/642885'}, {'Name': 'Fall', 'Rating': '74', 'Genre': 'Thriller', 'Release Date': '08/12/2022 ', 'Run Time': '1h 47m', 'Director': 'Scott Mann', 'URL': 'https://www.themoviedb.org/movie/985939'}]
# Project Gemini
# Serik Beyseu
# No director_name
# No director_name
# No director_name
# [{'Name': 'Terrifier 2', 'Rating': '74', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/28/2022 ', 'Run Time': '2h 18m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/663712'}, {'Name': 'Black Adam', 'Rating': '70', 'Genre': 'Action,\xa0Fantasy,\xa0Science Fiction', 'Release Date': '10/21/2022 ', 'Run Time': '2h 5m', 'Director': 'Jaume Collet-Serra', 'URL': 'https://www.themoviedb.org/movie/436270'}, {'Name': 'Jeepers Creepers: Reborn', 'Rating': '58', 'Genre': 'Horror,\xa0Thriller,\xa0Mystery', 'Release Date': '09/15/2022 ', 'Run Time': '1h 28m', 'Director': 'Timo Vuorensola', 'URL': 'https://www.themoviedb.org/movie/717728'}, {'Name': 'Fullmetal Alchemist: The Final Alchemy', 'Rating': '62', 'Genre': 'Action,\xa0Adventure,\xa0Fantasy', 'Release Date': '06/24/2022 ', 'Run Time': '2h 23m', 'Director': 'Fumihiko Sori', 'URL': 'https://www.themoviedb.org/movie/960704'}, {'Name': 'Orphan: First Kill', 'Rating': '68', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/17/2022 ', 'Run Time': '1h 39m', 'Director': 'William Brent Bell', 'URL': 'https://www.themoviedb.org/movie/760161'}, {'Name': 'Hocus Pocus 2', 'Rating': '76', 'Genre': 'Fantasy,\xa0Comedy,\xa0Family', 'Release Date': '09/30/2022 ', 'Run Time': '1h 47m', 'Director': 'Anne Fletcher', 'URL': 'https://www.themoviedb.org/movie/642885'}, {'Name': 'Fall', 'Rating': '74', 'Genre': 'Thriller', 'Release Date': '08/12/2022 ', 'Run Time': '1h 47m', 'Director': 'Scott Mann', 'URL': 'https://www.themoviedb.org/movie/985939'}, {'Name': 'Project Gemini', 'Rating': '56', 'Genre': 'Science Fiction', 'Release Date': '01/06/2022 ', 'Run Time': '1h 38m', 'Director': 'Serik Beyseu', 'URL': 'https://www.themoviedb.org/movie/575322'}]
# Halloween Ends
# David Gordon Green
# No director_name
# No director_name
# No director_name
# No director_name
# No director_name
# [{'Name': 'Terrifier 2', 'Rating': '74', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/28/2022 ', 'Run Time': '2h 18m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/663712'}, {'Name': 'Black Adam', 'Rating': '70', 'Genre': 'Action,\xa0Fantasy,\xa0Science Fiction', 'Release Date': '10/21/2022 ', 'Run Time': '2h 5m', 'Director': 'Jaume Collet-Serra', 'URL': 'https://www.themoviedb.org/movie/436270'}, {'Name': 'Jeepers Creepers: Reborn', 'Rating': '58', 'Genre': 'Horror,\xa0Thriller,\xa0Mystery', 'Release Date': '09/15/2022 ', 'Run Time': '1h 28m', 'Director': 'Timo Vuorensola', 'URL': 'https://www.themoviedb.org/movie/717728'}, {'Name': 'Fullmetal Alchemist: The Final Alchemy', 'Rating': '62', 'Genre': 'Action,\xa0Adventure,\xa0Fantasy', 'Release Date': '06/24/2022 ', 'Run Time': '2h 23m', 'Director': 'Fumihiko Sori', 'URL': 'https://www.themoviedb.org/movie/960704'}, {'Name': 'Orphan: First Kill', 'Rating': '68', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/17/2022 ', 'Run Time': '1h 39m', 'Director': 'William Brent Bell', 'URL': 'https://www.themoviedb.org/movie/760161'}, {'Name': 'Hocus Pocus 2', 'Rating': '76', 'Genre': 'Fantasy,\xa0Comedy,\xa0Family', 'Release Date': '09/30/2022 ', 'Run Time': '1h 47m', 'Director': 'Anne Fletcher', 'URL': 'https://www.themoviedb.org/movie/642885'}, {'Name': 'Fall', 'Rating': '74', 'Genre': 'Thriller', 'Release Date': '08/12/2022 ', 'Run Time': '1h 47m', 'Director': 'Scott Mann', 'URL': 'https://www.themoviedb.org/movie/985939'}, {'Name': 'Project Gemini', 'Rating': '56', 'Genre': 'Science Fiction', 'Release Date': '01/06/2022 ', 'Run Time': '1h 38m', 'Director': 'Serik Beyseu', 'URL': 'https://www.themoviedb.org/movie/575322'}, {'Name': 'Halloween Ends', 'Rating': '67', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/14/2022 ', 'Run Time': '1h 51m', 'Director': 'David Gordon Green', 'URL': 'https://www.themoviedb.org/movie/616820'}]
# The Battle at Lake Changjin: Water Gate Bridge
# Tsui Hark
# No director_name
# No director_name
# No director_name
# [{'Name': 'Terrifier 2', 'Rating': '74', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/28/2022 ', 'Run Time': '2h 18m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/663712'}, {'Name': 'Black Adam', 'Rating': '70', 'Genre': 'Action,\xa0Fantasy,\xa0Science Fiction', 'Release Date': '10/21/2022 ', 'Run Time': '2h 5m', 'Director': 'Jaume Collet-Serra', 'URL': 'https://www.themoviedb.org/movie/436270'}, {'Name': 'Jeepers Creepers: Reborn', 'Rating': '58', 'Genre': 'Horror,\xa0Thriller,\xa0Mystery', 'Release Date': '09/15/2022 ', 'Run Time': '1h 28m', 'Director': 'Timo Vuorensola', 'URL': 'https://www.themoviedb.org/movie/717728'}, {'Name': 'Fullmetal Alchemist: The Final Alchemy', 'Rating': '62', 'Genre': 'Action,\xa0Adventure,\xa0Fantasy', 'Release Date': '06/24/2022 ', 'Run Time': '2h 23m', 'Director': 'Fumihiko Sori', 'URL': 'https://www.themoviedb.org/movie/960704'}, {'Name': 'Orphan: First Kill', 'Rating': '68', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/17/2022 ', 'Run Time': '1h 39m', 'Director': 'William Brent Bell', 'URL': 'https://www.themoviedb.org/movie/760161'}, {'Name': 'Hocus Pocus 2', 'Rating': '76', 'Genre': 'Fantasy,\xa0Comedy,\xa0Family', 'Release Date': '09/30/2022 ', 'Run Time': '1h 47m', 'Director': 'Anne Fletcher', 'URL': 'https://www.themoviedb.org/movie/642885'}, {'Name': 'Fall', 'Rating': '74', 'Genre': 'Thriller', 'Release Date': '08/12/2022 ', 'Run Time': '1h 47m', 'Director': 'Scott Mann', 'URL': 'https://www.themoviedb.org/movie/985939'}, {'Name': 'Project Gemini', 'Rating': '56', 'Genre': 'Science Fiction', 'Release Date': '01/06/2022 ', 'Run Time': '1h 38m', 'Director': 'Serik Beyseu', 'URL': 'https://www.themoviedb.org/movie/575322'}, {'Name': 'Halloween Ends', 'Rating': '67', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/14/2022 ', 'Run Time': '1h 51m', 'Director': 'David Gordon Green', 'URL': 'https://www.themoviedb.org/movie/616820'}, {'Name': 'The Battle at Lake Changjin: Water Gate Bridge', 'Rating': '63', 'Genre': 'War,\xa0History,\xa0Action,\xa0Drama', 'Release Date': '02/01/2022 ', 'Run Time': '2h 29m', 'Director': 'Tsui Hark', 'URL': 'https://www.themoviedb.org/movie/928123'}]
# Bullet Train
# David Leitch
# No director_name
# [{'Name': 'Terrifier 2', 'Rating': '74', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/28/2022 ', 'Run Time': '2h 18m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/663712'}, {'Name': 'Black Adam', 'Rating': '70', 'Genre': 'Action,\xa0Fantasy,\xa0Science Fiction', 'Release Date': '10/21/2022 ', 'Run Time': '2h 5m', 'Director': 'Jaume Collet-Serra', 'URL': 'https://www.themoviedb.org/movie/436270'}, {'Name': 'Jeepers Creepers: Reborn', 'Rating': '58', 'Genre': 'Horror,\xa0Thriller,\xa0Mystery', 'Release Date': '09/15/2022 ', 'Run Time': '1h 28m', 'Director': 'Timo Vuorensola', 'URL': 'https://www.themoviedb.org/movie/717728'}, {'Name': 'Fullmetal Alchemist: The Final Alchemy', 'Rating': '62', 'Genre': 'Action,\xa0Adventure,\xa0Fantasy', 'Release Date': '06/24/2022 ', 'Run Time': '2h 23m', 'Director': 'Fumihiko Sori', 'URL': 'https://www.themoviedb.org/movie/960704'}, {'Name': 'Orphan: First Kill', 'Rating': '68', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/17/2022 ', 'Run Time': '1h 39m', 'Director': 'William Brent Bell', 'URL': 'https://www.themoviedb.org/movie/760161'}, {'Name': 'Hocus Pocus 2', 'Rating': '76', 'Genre': 'Fantasy,\xa0Comedy,\xa0Family', 'Release Date': '09/30/2022 ', 'Run Time': '1h 47m', 'Director': 'Anne Fletcher', 'URL': 'https://www.themoviedb.org/movie/642885'}, {'Name': 'Fall', 'Rating': '74', 'Genre': 'Thriller', 'Release Date': '08/12/2022 ', 'Run Time': '1h 47m', 'Director': 'Scott Mann', 'URL': 'https://www.themoviedb.org/movie/985939'}, {'Name': 'Project Gemini', 'Rating': '56', 'Genre': 'Science Fiction', 'Release Date': '01/06/2022 ', 'Run Time': '1h 38m', 'Director': 'Serik Beyseu', 'URL': 'https://www.themoviedb.org/movie/575322'}, {'Name': 'Halloween Ends', 'Rating': '67', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/14/2022 ', 'Run Time': '1h 51m', 'Director': 'David Gordon Green', 'URL': 'https://www.themoviedb.org/movie/616820'}, {'Name': 'The Battle at Lake Changjin: Water Gate Bridge', 'Rating': '63', 'Genre': 'War,\xa0History,\xa0Action,\xa0Drama', 'Release Date': '02/01/2022 ', 'Run Time': '2h 29m', 'Director': 'Tsui Hark', 'URL': 'https://www.themoviedb.org/movie/928123'}, {'Name': 'Bullet Train', 'Rating': '75', 'Genre': 'Action,\xa0Comedy,\xa0Thriller', 'Release Date': '08/05/2022 ', 'Run Time': '2h 7m', 'Director': 'David Leitch', 'URL': 'https://www.themoviedb.org/movie/718930'}]
# Piggy
# Carlota Pereda
# [{'Name': 'Terrifier 2', 'Rating': '74', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/28/2022 ', 'Run Time': '2h 18m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/663712'}, {'Name': 'Black Adam', 'Rating': '70', 'Genre': 'Action,\xa0Fantasy,\xa0Science Fiction', 'Release Date': '10/21/2022 ', 'Run Time': '2h 5m', 'Director': 'Jaume Collet-Serra', 'URL': 'https://www.themoviedb.org/movie/436270'}, {'Name': 'Jeepers Creepers: Reborn', 'Rating': '58', 'Genre': 'Horror,\xa0Thriller,\xa0Mystery', 'Release Date': '09/15/2022 ', 'Run Time': '1h 28m', 'Director': 'Timo Vuorensola', 'URL': 'https://www.themoviedb.org/movie/717728'}, {'Name': 'Fullmetal Alchemist: The Final Alchemy', 'Rating': '62', 'Genre': 'Action,\xa0Adventure,\xa0Fantasy', 'Release Date': '06/24/2022 ', 'Run Time': '2h 23m', 'Director': 'Fumihiko Sori', 'URL': 'https://www.themoviedb.org/movie/960704'}, {'Name': 'Orphan: First Kill', 'Rating': '68', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/17/2022 ', 'Run Time': '1h 39m', 'Director': 'William Brent Bell', 'URL': 'https://www.themoviedb.org/movie/760161'}, {'Name': 'Hocus Pocus 2', 'Rating': '76', 'Genre': 'Fantasy,\xa0Comedy,\xa0Family', 'Release Date': '09/30/2022 ', 'Run Time': '1h 47m', 'Director': 'Anne Fletcher', 'URL': 'https://www.themoviedb.org/movie/642885'}, {'Name': 'Fall', 'Rating': '74', 'Genre': 'Thriller', 'Release Date': '08/12/2022 ', 'Run Time': '1h 47m', 'Director': 'Scott Mann', 'URL': 'https://www.themoviedb.org/movie/985939'}, {'Name': 'Project Gemini', 'Rating': '56', 'Genre': 'Science Fiction', 'Release Date': '01/06/2022 ', 'Run Time': '1h 38m', 'Director': 'Serik Beyseu', 'URL': 'https://www.themoviedb.org/movie/575322'}, {'Name': 'Halloween Ends', 'Rating': '67', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/14/2022 ', 'Run Time': '1h 51m', 'Director': 'David Gordon Green', 'URL': 'https://www.themoviedb.org/movie/616820'}, {'Name': 'The Battle at Lake Changjin: Water Gate Bridge', 'Rating': '63', 'Genre': 'War,\xa0History,\xa0Action,\xa0Drama', 'Release Date': '02/01/2022 ', 'Run Time': '2h 29m', 'Director': 'Tsui Hark', 'URL': 'https://www.themoviedb.org/movie/928123'}, {'Name': 'Bullet Train', 'Rating': '75', 'Genre': 'Action,\xa0Comedy,\xa0Thriller', 'Release Date': '08/05/2022 ', 'Run Time': '2h 7m', 'Director': 'David Leitch', 'URL': 'https://www.themoviedb.org/movie/718930'}, {'Name': 'Piggy', 'Rating': '68', 'Genre': 'Drama,\xa0Thriller,\xa0Horror', 'Release Date': '10/14/2022 ', 'Run Time': '1h 40m', 'Director': 'Carlota Pereda', 'URL': 'https://www.themoviedb.org/movie/848058'}]
# Crawlspace
# L. Gustavo Cooper
# No director_name
# [{'Name': 'Terrifier 2', 'Rating': '74', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/28/2022 ', 'Run Time': '2h 18m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/663712'}, {'Name': 'Black Adam', 'Rating': '70', 'Genre': 'Action,\xa0Fantasy,\xa0Science Fiction', 'Release Date': '10/21/2022 ', 'Run Time': '2h 5m', 'Director': 'Jaume Collet-Serra', 'URL': 'https://www.themoviedb.org/movie/436270'}, {'Name': 'Jeepers Creepers: Reborn', 'Rating': '58', 'Genre': 'Horror,\xa0Thriller,\xa0Mystery', 'Release Date': '09/15/2022 ', 'Run Time': '1h 28m', 'Director': 'Timo Vuorensola', 'URL': 'https://www.themoviedb.org/movie/717728'}, {'Name': 'Fullmetal Alchemist: The Final Alchemy', 'Rating': '62', 'Genre': 'Action,\xa0Adventure,\xa0Fantasy', 'Release Date': '06/24/2022 ', 'Run Time': '2h 23m', 'Director': 'Fumihiko Sori', 'URL': 'https://www.themoviedb.org/movie/960704'}, {'Name': 'Orphan: First Kill', 'Rating': '68', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/17/2022 ', 'Run Time': '1h 39m', 'Director': 'William Brent Bell', 'URL': 'https://www.themoviedb.org/movie/760161'}, {'Name': 'Hocus Pocus 2', 'Rating': '76', 'Genre': 'Fantasy,\xa0Comedy,\xa0Family', 'Release Date': '09/30/2022 ', 'Run Time': '1h 47m', 'Director': 'Anne Fletcher', 'URL': 'https://www.themoviedb.org/movie/642885'}, {'Name': 'Fall', 'Rating': '74', 'Genre': 'Thriller', 'Release Date': '08/12/2022 ', 'Run Time': '1h 47m', 'Director': 'Scott Mann', 'URL': 'https://www.themoviedb.org/movie/985939'}, {'Name': 'Project Gemini', 'Rating': '56', 'Genre': 'Science Fiction', 'Release Date': '01/06/2022 ', 'Run Time': '1h 38m', 'Director': 'Serik Beyseu', 'URL': 'https://www.themoviedb.org/movie/575322'}, {'Name': 'Halloween Ends', 'Rating': '67', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/14/2022 ', 'Run Time': '1h 51m', 'Director': 'David Gordon Green', 'URL': 'https://www.themoviedb.org/movie/616820'}, {'Name': 'The Battle at Lake Changjin: Water Gate Bridge', 'Rating': '63', 'Genre': 'War,\xa0History,\xa0Action,\xa0Drama', 'Release Date': '02/01/2022 ', 'Run Time': '2h 29m', 'Director': 'Tsui Hark', 'URL': 'https://www.themoviedb.org/movie/928123'}, {'Name': 'Bullet Train', 'Rating': '75', 'Genre': 'Action,\xa0Comedy,\xa0Thriller', 'Release Date': '08/05/2022 ', 'Run Time': '2h 7m', 'Director': 'David Leitch', 'URL': 'https://www.themoviedb.org/movie/718930'}, {'Name': 'Piggy', 'Rating': '68', 'Genre': 'Drama,\xa0Thriller,\xa0Horror', 'Release Date': '10/14/2022 ', 'Run Time': '1h 40m', 'Director': 'Carlota Pereda', 'URL': 'https://www.themoviedb.org/movie/848058'}, {'Name': 'Crawlspace', 'Rating': '73', 'Genre': 'Thriller', 'Release Date': '03/31/2022 ', 'Run Time': '1h 30m', 'Director': 'L. Gustavo Cooper', 'URL': 'https://www.themoviedb.org/movie/879538'}]
# The School for Good and Evil
# Paul Feig
# No director_name
# No director_name
# No director_name
# [{'Name': 'Terrifier 2', 'Rating': '74', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/28/2022 ', 'Run Time': '2h 18m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/663712'}, {'Name': 'Black Adam', 'Rating': '70', 'Genre': 'Action,\xa0Fantasy,\xa0Science Fiction', 'Release Date': '10/21/2022 ', 'Run Time': '2h 5m', 'Director': 'Jaume Collet-Serra', 'URL': 'https://www.themoviedb.org/movie/436270'}, {'Name': 'Jeepers Creepers: Reborn', 'Rating': '58', 'Genre': 'Horror,\xa0Thriller,\xa0Mystery', 'Release Date': '09/15/2022 ', 'Run Time': '1h 28m', 'Director': 'Timo Vuorensola', 'URL': 'https://www.themoviedb.org/movie/717728'}, {'Name': 'Fullmetal Alchemist: The Final Alchemy', 'Rating': '62', 'Genre': 'Action,\xa0Adventure,\xa0Fantasy', 'Release Date': '06/24/2022 ', 'Run Time': '2h 23m', 'Director': 'Fumihiko Sori', 'URL': 'https://www.themoviedb.org/movie/960704'}, {'Name': 'Orphan: First Kill', 'Rating': '68', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/17/2022 ', 'Run Time': '1h 39m', 'Director': 'William Brent Bell', 'URL': 'https://www.themoviedb.org/movie/760161'}, {'Name': 'Hocus Pocus 2', 'Rating': '76', 'Genre': 'Fantasy,\xa0Comedy,\xa0Family', 'Release Date': '09/30/2022 ', 'Run Time': '1h 47m', 'Director': 'Anne Fletcher', 'URL': 'https://www.themoviedb.org/movie/642885'}, {'Name': 'Fall', 'Rating': '74', 'Genre': 'Thriller', 'Release Date': '08/12/2022 ', 'Run Time': '1h 47m', 'Director': 'Scott Mann', 'URL': 'https://www.themoviedb.org/movie/985939'}, {'Name': 'Project Gemini', 'Rating': '56', 'Genre': 'Science Fiction', 'Release Date': '01/06/2022 ', 'Run Time': '1h 38m', 'Director': 'Serik Beyseu', 'URL': 'https://www.themoviedb.org/movie/575322'}, {'Name': 'Halloween Ends', 'Rating': '67', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/14/2022 ', 'Run Time': '1h 51m', 'Director': 'David Gordon Green', 'URL': 'https://www.themoviedb.org/movie/616820'}, {'Name': 'The Battle at Lake Changjin: Water Gate Bridge', 'Rating': '63', 'Genre': 'War,\xa0History,\xa0Action,\xa0Drama', 'Release Date': '02/01/2022 ', 'Run Time': '2h 29m', 'Director': 'Tsui Hark', 'URL': 'https://www.themoviedb.org/movie/928123'}, {'Name': 'Bullet Train', 'Rating': '75', 'Genre': 'Action,\xa0Comedy,\xa0Thriller', 'Release Date': '08/05/2022 ', 'Run Time': '2h 7m', 'Director': 'David Leitch', 'URL': 'https://www.themoviedb.org/movie/718930'}, {'Name': 'Piggy', 'Rating': '68', 'Genre': 'Drama,\xa0Thriller,\xa0Horror', 'Release Date': '10/14/2022 ', 'Run Time': '1h 40m', 'Director': 'Carlota Pereda', 'URL': 'https://www.themoviedb.org/movie/848058'}, {'Name': 'Crawlspace', 'Rating': '73', 'Genre': 'Thriller', 'Release Date': '03/31/2022 ', 'Run Time': '1h 30m', 'Director': 'L. Gustavo Cooper', 'URL': 'https://www.themoviedb.org/movie/879538'}, {'Name': 'The School for Good and Evil', 'Rating': '73', 'Genre': 'Fantasy,\xa0Action,\xa0Drama', 'Release Date': '10/19/2022 ', 'Run Time': '2h 26m', 'Director': 'Paul Feig', 'URL': 'https://www.themoviedb.org/movie/779782'}]
# Coco
# Lee Unkrich
# No director_name
# No director_name
# No director_name
# [{'Name': 'Terrifier 2', 'Rating': '74', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/28/2022 ', 'Run Time': '2h 18m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/663712'}, {'Name': 'Black Adam', 'Rating': '70', 'Genre': 'Action,\xa0Fantasy,\xa0Science Fiction', 'Release Date': '10/21/2022 ', 'Run Time': '2h 5m', 'Director': 'Jaume Collet-Serra', 'URL': 'https://www.themoviedb.org/movie/436270'}, {'Name': 'Jeepers Creepers: Reborn', 'Rating': '58', 'Genre': 'Horror,\xa0Thriller,\xa0Mystery', 'Release Date': '09/15/2022 ', 'Run Time': '1h 28m', 'Director': 'Timo Vuorensola', 'URL': 'https://www.themoviedb.org/movie/717728'}, {'Name': 'Fullmetal Alchemist: The Final Alchemy', 'Rating': '62', 'Genre': 'Action,\xa0Adventure,\xa0Fantasy', 'Release Date': '06/24/2022 ', 'Run Time': '2h 23m', 'Director': 'Fumihiko Sori', 'URL': 'https://www.themoviedb.org/movie/960704'}, {'Name': 'Orphan: First Kill', 'Rating': '68', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/17/2022 ', 'Run Time': '1h 39m', 'Director': 'William Brent Bell', 'URL': 'https://www.themoviedb.org/movie/760161'}, {'Name': 'Hocus Pocus 2', 'Rating': '76', 'Genre': 'Fantasy,\xa0Comedy,\xa0Family', 'Release Date': '09/30/2022 ', 'Run Time': '1h 47m', 'Director': 'Anne Fletcher', 'URL': 'https://www.themoviedb.org/movie/642885'}, {'Name': 'Fall', 'Rating': '74', 'Genre': 'Thriller', 'Release Date': '08/12/2022 ', 'Run Time': '1h 47m', 'Director': 'Scott Mann', 'URL': 'https://www.themoviedb.org/movie/985939'}, {'Name': 'Project Gemini', 'Rating': '56', 'Genre': 'Science Fiction', 'Release Date': '01/06/2022 ', 'Run Time': '1h 38m', 'Director': 'Serik Beyseu', 'URL': 'https://www.themoviedb.org/movie/575322'}, {'Name': 'Halloween Ends', 'Rating': '67', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/14/2022 ', 'Run Time': '1h 51m', 'Director': 'David Gordon Green', 'URL': 'https://www.themoviedb.org/movie/616820'}, {'Name': 'The Battle at Lake Changjin: Water Gate Bridge', 'Rating': '63', 'Genre': 'War,\xa0History,\xa0Action,\xa0Drama', 'Release Date': '02/01/2022 ', 'Run Time': '2h 29m', 'Director': 'Tsui Hark', 'URL': 'https://www.themoviedb.org/movie/928123'}, {'Name': 'Bullet Train', 'Rating': '75', 'Genre': 'Action,\xa0Comedy,\xa0Thriller', 'Release Date': '08/05/2022 ', 'Run Time': '2h 7m', 'Director': 'David Leitch', 'URL': 'https://www.themoviedb.org/movie/718930'}, {'Name': 'Piggy', 'Rating': '68', 'Genre': 'Drama,\xa0Thriller,\xa0Horror', 'Release Date': '10/14/2022 ', 'Run Time': '1h 40m', 'Director': 'Carlota Pereda', 'URL': 'https://www.themoviedb.org/movie/848058'}, {'Name': 'Crawlspace', 'Rating': '73', 'Genre': 'Thriller', 'Release Date': '03/31/2022 ', 'Run Time': '1h 30m', 'Director': 'L. Gustavo Cooper', 'URL': 'https://www.themoviedb.org/movie/879538'}, {'Name': 'The School for Good and Evil', 'Rating': '73', 'Genre': 'Fantasy,\xa0Action,\xa0Drama', 'Release Date': '10/19/2022 ', 'Run Time': '2h 26m', 'Director': 'Paul Feig', 'URL': 'https://www.themoviedb.org/movie/779782'}, {'Name': 'Coco', 'Rating': '82', 'Genre': 'Family,\xa0Animation,\xa0Fantasy,\xa0Music,\xa0Comedy,\xa0Adventure', 'Release Date': '11/24/2017 ', 'Run Time': '1h 45m', 'Director': 'Lee Unkrich', 'URL': 'https://www.themoviedb.org/movie/354912'}]
# Terrifier
# Damien Leone
# [{'Name': 'Terrifier 2', 'Rating': '74', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/28/2022 ', 'Run Time': '2h 18m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/663712'}, {'Name': 'Black Adam', 'Rating': '70', 'Genre': 'Action,\xa0Fantasy,\xa0Science Fiction', 'Release Date': '10/21/2022 ', 'Run Time': '2h 5m', 'Director': 'Jaume Collet-Serra', 'URL': 'https://www.themoviedb.org/movie/436270'}, {'Name': 'Jeepers Creepers: Reborn', 'Rating': '58', 'Genre': 'Horror,\xa0Thriller,\xa0Mystery', 'Release Date': '09/15/2022 ', 'Run Time': '1h 28m', 'Director': 'Timo Vuorensola', 'URL': 'https://www.themoviedb.org/movie/717728'}, {'Name': 'Fullmetal Alchemist: The Final Alchemy', 'Rating': '62', 'Genre': 'Action,\xa0Adventure,\xa0Fantasy', 'Release Date': '06/24/2022 ', 'Run Time': '2h 23m', 'Director': 'Fumihiko Sori', 'URL': 'https://www.themoviedb.org/movie/960704'}, {'Name': 'Orphan: First Kill', 'Rating': '68', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/17/2022 ', 'Run Time': '1h 39m', 'Director': 'William Brent Bell', 'URL': 'https://www.themoviedb.org/movie/760161'}, {'Name': 'Hocus Pocus 2', 'Rating': '76', 'Genre': 'Fantasy,\xa0Comedy,\xa0Family', 'Release Date': '09/30/2022 ', 'Run Time': '1h 47m', 'Director': 'Anne Fletcher', 'URL': 'https://www.themoviedb.org/movie/642885'}, {'Name': 'Fall', 'Rating': '74', 'Genre': 'Thriller', 'Release Date': '08/12/2022 ', 'Run Time': '1h 47m', 'Director': 'Scott Mann', 'URL': 'https://www.themoviedb.org/movie/985939'}, {'Name': 'Project Gemini', 'Rating': '56', 'Genre': 'Science Fiction', 'Release Date': '01/06/2022 ', 'Run Time': '1h 38m', 'Director': 'Serik Beyseu', 'URL': 'https://www.themoviedb.org/movie/575322'}, {'Name': 'Halloween Ends', 'Rating': '67', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/14/2022 ', 'Run Time': '1h 51m', 'Director': 'David Gordon Green', 'URL': 'https://www.themoviedb.org/movie/616820'}, {'Name': 'The Battle at Lake Changjin: Water Gate Bridge', 'Rating': '63', 'Genre': 'War,\xa0History,\xa0Action,\xa0Drama', 'Release Date': '02/01/2022 ', 'Run Time': '2h 29m', 'Director': 'Tsui Hark', 'URL': 'https://www.themoviedb.org/movie/928123'}, {'Name': 'Bullet Train', 'Rating': '75', 'Genre': 'Action,\xa0Comedy,\xa0Thriller', 'Release Date': '08/05/2022 ', 'Run Time': '2h 7m', 'Director': 'David Leitch', 'URL': 'https://www.themoviedb.org/movie/718930'}, {'Name': 'Piggy', 'Rating': '68', 'Genre': 'Drama,\xa0Thriller,\xa0Horror', 'Release Date': '10/14/2022 ', 'Run Time': '1h 40m', 'Director': 'Carlota Pereda', 'URL': 'https://www.themoviedb.org/movie/848058'}, {'Name': 'Crawlspace', 'Rating': '73', 'Genre': 'Thriller', 'Release Date': '03/31/2022 ', 'Run Time': '1h 30m', 'Director': 'L. Gustavo Cooper', 'URL': 'https://www.themoviedb.org/movie/879538'}, {'Name': 'The School for Good and Evil', 'Rating': '73', 'Genre': 'Fantasy,\xa0Action,\xa0Drama', 'Release Date': '10/19/2022 ', 'Run Time': '2h 26m', 'Director': 'Paul Feig', 'URL': 'https://www.themoviedb.org/movie/779782'}, {'Name': 'Coco', 'Rating': '82', 'Genre': 'Family,\xa0Animation,\xa0Fantasy,\xa0Music,\xa0Comedy,\xa0Adventure', 'Release Date': '11/24/2017 ', 'Run Time': '1h 45m', 'Director': 'Lee Unkrich', 'URL': 'https://www.themoviedb.org/movie/354912'}, {'Name': 'Terrifier', 'Rating': '65', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/15/2016 ', 'Run Time': '1h 24m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/420634'}]
# Code Name Banshee
# Jon Keeyes
# No director_name
# [{'Name': 'Terrifier 2', 'Rating': '74', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/28/2022 ', 'Run Time': '2h 18m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/663712'}, {'Name': 'Black Adam', 'Rating': '70', 'Genre': 'Action,\xa0Fantasy,\xa0Science Fiction', 'Release Date': '10/21/2022 ', 'Run Time': '2h 5m', 'Director': 'Jaume Collet-Serra', 'URL': 'https://www.themoviedb.org/movie/436270'}, {'Name': 'Jeepers Creepers: Reborn', 'Rating': '58', 'Genre': 'Horror,\xa0Thriller,\xa0Mystery', 'Release Date': '09/15/2022 ', 'Run Time': '1h 28m', 'Director': 'Timo Vuorensola', 'URL': 'https://www.themoviedb.org/movie/717728'}, {'Name': 'Fullmetal Alchemist: The Final Alchemy', 'Rating': '62', 'Genre': 'Action,\xa0Adventure,\xa0Fantasy', 'Release Date': '06/24/2022 ', 'Run Time': '2h 23m', 'Director': 'Fumihiko Sori', 'URL': 'https://www.themoviedb.org/movie/960704'}, {'Name': 'Orphan: First Kill', 'Rating': '68', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/17/2022 ', 'Run Time': '1h 39m', 'Director': 'William Brent Bell', 'URL': 'https://www.themoviedb.org/movie/760161'}, {'Name': 'Hocus Pocus 2', 'Rating': '76', 'Genre': 'Fantasy,\xa0Comedy,\xa0Family', 'Release Date': '09/30/2022 ', 'Run Time': '1h 47m', 'Director': 'Anne Fletcher', 'URL': 'https://www.themoviedb.org/movie/642885'}, {'Name': 'Fall', 'Rating': '74', 'Genre': 'Thriller', 'Release Date': '08/12/2022 ', 'Run Time': '1h 47m', 'Director': 'Scott Mann', 'URL': 'https://www.themoviedb.org/movie/985939'}, {'Name': 'Project Gemini', 'Rating': '56', 'Genre': 'Science Fiction', 'Release Date': '01/06/2022 ', 'Run Time': '1h 38m', 'Director': 'Serik Beyseu', 'URL': 'https://www.themoviedb.org/movie/575322'}, {'Name': 'Halloween Ends', 'Rating': '67', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/14/2022 ', 'Run Time': '1h 51m', 'Director': 'David Gordon Green', 'URL': 'https://www.themoviedb.org/movie/616820'}, {'Name': 'The Battle at Lake Changjin: Water Gate Bridge', 'Rating': '63', 'Genre': 'War,\xa0History,\xa0Action,\xa0Drama', 'Release Date': '02/01/2022 ', 'Run Time': '2h 29m', 'Director': 'Tsui Hark', 'URL': 'https://www.themoviedb.org/movie/928123'}, {'Name': 'Bullet Train', 'Rating': '75', 'Genre': 'Action,\xa0Comedy,\xa0Thriller', 'Release Date': '08/05/2022 ', 'Run Time': '2h 7m', 'Director': 'David Leitch', 'URL': 'https://www.themoviedb.org/movie/718930'}, {'Name': 'Piggy', 'Rating': '68', 'Genre': 'Drama,\xa0Thriller,\xa0Horror', 'Release Date': '10/14/2022 ', 'Run Time': '1h 40m', 'Director': 'Carlota Pereda', 'URL': 'https://www.themoviedb.org/movie/848058'}, {'Name': 'Crawlspace', 'Rating': '73', 'Genre': 'Thriller', 'Release Date': '03/31/2022 ', 'Run Time': '1h 30m', 'Director': 'L. Gustavo Cooper', 'URL': 'https://www.themoviedb.org/movie/879538'}, {'Name': 'The School for Good and Evil', 'Rating': '73', 'Genre': 'Fantasy,\xa0Action,\xa0Drama', 'Release Date': '10/19/2022 ', 'Run Time': '2h 26m', 'Director': 'Paul Feig', 'URL': 'https://www.themoviedb.org/movie/779782'}, {'Name': 'Coco', 'Rating': '82', 'Genre': 'Family,\xa0Animation,\xa0Fantasy,\xa0Music,\xa0Comedy,\xa0Adventure', 'Release Date': '11/24/2017 ', 'Run Time': '1h 45m', 'Director': 'Lee Unkrich', 'URL': 'https://www.themoviedb.org/movie/354912'}, {'Name': 'Terrifier', 'Rating': '65', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/15/2016 ', 'Run Time': '1h 24m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/420634'}, {'Name': 'Code Name Banshee', 'Rating': '48', 'Genre': 'Thriller,\xa0Action', 'Release Date': '07/14/2022 ', 'Run Time': '1h 33m', 'Director': 'Jon Keeyes', 'URL': 'https://www.themoviedb.org/movie/916719'}]
# The Infernal Machine
# Andrew Hunt
# [{'Name': 'Terrifier 2', 'Rating': '74', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/28/2022 ', 'Run Time': '2h 18m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/663712'}, {'Name': 'Black Adam', 'Rating': '70', 'Genre': 'Action,\xa0Fantasy,\xa0Science Fiction', 'Release Date': '10/21/2022 ', 'Run Time': '2h 5m', 'Director': 'Jaume Collet-Serra', 'URL': 'https://www.themoviedb.org/movie/436270'}, {'Name': 'Jeepers Creepers: Reborn', 'Rating': '58', 'Genre': 'Horror,\xa0Thriller,\xa0Mystery', 'Release Date': '09/15/2022 ', 'Run Time': '1h 28m', 'Director': 'Timo Vuorensola', 'URL': 'https://www.themoviedb.org/movie/717728'}, {'Name': 'Fullmetal Alchemist: The Final Alchemy', 'Rating': '62', 'Genre': 'Action,\xa0Adventure,\xa0Fantasy', 'Release Date': '06/24/2022 ', 'Run Time': '2h 23m', 'Director': 'Fumihiko Sori', 'URL': 'https://www.themoviedb.org/movie/960704'}, {'Name': 'Orphan: First Kill', 'Rating': '68', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/17/2022 ', 'Run Time': '1h 39m', 'Director': 'William Brent Bell', 'URL': 'https://www.themoviedb.org/movie/760161'}, {'Name': 'Hocus Pocus 2', 'Rating': '76', 'Genre': 'Fantasy,\xa0Comedy,\xa0Family', 'Release Date': '09/30/2022 ', 'Run Time': '1h 47m', 'Director': 'Anne Fletcher', 'URL': 'https://www.themoviedb.org/movie/642885'}, {'Name': 'Fall', 'Rating': '74', 'Genre': 'Thriller', 'Release Date': '08/12/2022 ', 'Run Time': '1h 47m', 'Director': 'Scott Mann', 'URL': 'https://www.themoviedb.org/movie/985939'}, {'Name': 'Project Gemini', 'Rating': '56', 'Genre': 'Science Fiction', 'Release Date': '01/06/2022 ', 'Run Time': '1h 38m', 'Director': 'Serik Beyseu', 'URL': 'https://www.themoviedb.org/movie/575322'}, {'Name': 'Halloween Ends', 'Rating': '67', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/14/2022 ', 'Run Time': '1h 51m', 'Director': 'David Gordon Green', 'URL': 'https://www.themoviedb.org/movie/616820'}, {'Name': 'The Battle at Lake Changjin: Water Gate Bridge', 'Rating': '63', 'Genre': 'War,\xa0History,\xa0Action,\xa0Drama', 'Release Date': '02/01/2022 ', 'Run Time': '2h 29m', 'Director': 'Tsui Hark', 'URL': 'https://www.themoviedb.org/movie/928123'}, {'Name': 'Bullet Train', 'Rating': '75', 'Genre': 'Action,\xa0Comedy,\xa0Thriller', 'Release Date': '08/05/2022 ', 'Run Time': '2h 7m', 'Director': 'David Leitch', 'URL': 'https://www.themoviedb.org/movie/718930'}, {'Name': 'Piggy', 'Rating': '68', 'Genre': 'Drama,\xa0Thriller,\xa0Horror', 'Release Date': '10/14/2022 ', 'Run Time': '1h 40m', 'Director': 'Carlota Pereda', 'URL': 'https://www.themoviedb.org/movie/848058'}, {'Name': 'Crawlspace', 'Rating': '73', 'Genre': 'Thriller', 'Release Date': '03/31/2022 ', 'Run Time': '1h 30m', 'Director': 'L. Gustavo Cooper', 'URL': 'https://www.themoviedb.org/movie/879538'}, {'Name': 'The School for Good and Evil', 'Rating': '73', 'Genre': 'Fantasy,\xa0Action,\xa0Drama', 'Release Date': '10/19/2022 ', 'Run Time': '2h 26m', 'Director': 'Paul Feig', 'URL': 'https://www.themoviedb.org/movie/779782'}, {'Name': 'Coco', 'Rating': '82', 'Genre': 'Family,\xa0Animation,\xa0Fantasy,\xa0Music,\xa0Comedy,\xa0Adventure', 'Release Date': '11/24/2017 ', 'Run Time': '1h 45m', 'Director': 'Lee Unkrich', 'URL': 'https://www.themoviedb.org/movie/354912'}, {'Name': 'Terrifier', 'Rating': '65', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/15/2016 ', 'Run Time': '1h 24m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/420634'}, {'Name': 'Code Name Banshee', 'Rating': '48', 'Genre': 'Thriller,\xa0Action', 'Release Date': '07/14/2022 ', 'Run Time': '1h 33m', 'Director': 'Jon Keeyes', 'URL': 'https://www.themoviedb.org/movie/916719'}, {'Name': 'The Infernal Machine', 'Rating': '70', 'Genre': 'Thriller,\xa0Mystery', 'Release Date': '09/23/2022 ', 'Run Time': '1h 47m', 'Director': 'Andrew Hunt', 'URL': 'https://www.themoviedb.org/movie/916605'}]
# Athena
# Romain Gavras
# No director_name
# No director_name
# [{'Name': 'Terrifier 2', 'Rating': '74', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/28/2022 ', 'Run Time': '2h 18m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/663712'}, {'Name': 'Black Adam', 'Rating': '70', 'Genre': 'Action,\xa0Fantasy,\xa0Science Fiction', 'Release Date': '10/21/2022 ', 'Run Time': '2h 5m', 'Director': 'Jaume Collet-Serra', 'URL': 'https://www.themoviedb.org/movie/436270'}, {'Name': 'Jeepers Creepers: Reborn', 'Rating': '58', 'Genre': 'Horror,\xa0Thriller,\xa0Mystery', 'Release Date': '09/15/2022 ', 'Run Time': '1h 28m', 'Director': 'Timo Vuorensola', 'URL': 'https://www.themoviedb.org/movie/717728'}, {'Name': 'Fullmetal Alchemist: The Final Alchemy', 'Rating': '62', 'Genre': 'Action,\xa0Adventure,\xa0Fantasy', 'Release Date': '06/24/2022 ', 'Run Time': '2h 23m', 'Director': 'Fumihiko Sori', 'URL': 'https://www.themoviedb.org/movie/960704'}, {'Name': 'Orphan: First Kill', 'Rating': '68', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/17/2022 ', 'Run Time': '1h 39m', 'Director': 'William Brent Bell', 'URL': 'https://www.themoviedb.org/movie/760161'}, {'Name': 'Hocus Pocus 2', 'Rating': '76', 'Genre': 'Fantasy,\xa0Comedy,\xa0Family', 'Release Date': '09/30/2022 ', 'Run Time': '1h 47m', 'Director': 'Anne Fletcher', 'URL': 'https://www.themoviedb.org/movie/642885'}, {'Name': 'Fall', 'Rating': '74', 'Genre': 'Thriller', 'Release Date': '08/12/2022 ', 'Run Time': '1h 47m', 'Director': 'Scott Mann', 'URL': 'https://www.themoviedb.org/movie/985939'}, {'Name': 'Project Gemini', 'Rating': '56', 'Genre': 'Science Fiction', 'Release Date': '01/06/2022 ', 'Run Time': '1h 38m', 'Director': 'Serik Beyseu', 'URL': 'https://www.themoviedb.org/movie/575322'}, {'Name': 'Halloween Ends', 'Rating': '67', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/14/2022 ', 'Run Time': '1h 51m', 'Director': 'David Gordon Green', 'URL': 'https://www.themoviedb.org/movie/616820'}, {'Name': 'The Battle at Lake Changjin: Water Gate Bridge', 'Rating': '63', 'Genre': 'War,\xa0History,\xa0Action,\xa0Drama', 'Release Date': '02/01/2022 ', 'Run Time': '2h 29m', 'Director': 'Tsui Hark', 'URL': 'https://www.themoviedb.org/movie/928123'}, {'Name': 'Bullet Train', 'Rating': '75', 'Genre': 'Action,\xa0Comedy,\xa0Thriller', 'Release Date': '08/05/2022 ', 'Run Time': '2h 7m', 'Director': 'David Leitch', 'URL': 'https://www.themoviedb.org/movie/718930'}, {'Name': 'Piggy', 'Rating': '68', 'Genre': 'Drama,\xa0Thriller,\xa0Horror', 'Release Date': '10/14/2022 ', 'Run Time': '1h 40m', 'Director': 'Carlota Pereda', 'URL': 'https://www.themoviedb.org/movie/848058'}, {'Name': 'Crawlspace', 'Rating': '73', 'Genre': 'Thriller', 'Release Date': '03/31/2022 ', 'Run Time': '1h 30m', 'Director': 'L. Gustavo Cooper', 'URL': 'https://www.themoviedb.org/movie/879538'}, {'Name': 'The School for Good and Evil', 'Rating': '73', 'Genre': 'Fantasy,\xa0Action,\xa0Drama', 'Release Date': '10/19/2022 ', 'Run Time': '2h 26m', 'Director': 'Paul Feig', 'URL': 'https://www.themoviedb.org/movie/779782'}, {'Name': 'Coco', 'Rating': '82', 'Genre': 'Family,\xa0Animation,\xa0Fantasy,\xa0Music,\xa0Comedy,\xa0Adventure', 'Release Date': '11/24/2017 ', 'Run Time': '1h 45m', 'Director': 'Lee Unkrich', 'URL': 'https://www.themoviedb.org/movie/354912'}, {'Name': 'Terrifier', 'Rating': '65', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/15/2016 ', 'Run Time': '1h 24m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/420634'}, {'Name': 'Code Name Banshee', 'Rating': '48', 'Genre': 'Thriller,\xa0Action', 'Release Date': '07/14/2022 ', 'Run Time': '1h 33m', 'Director': 'Jon Keeyes', 'URL': 'https://www.themoviedb.org/movie/916719'}, {'Name': 'The Infernal Machine', 'Rating': '70', 'Genre': 'Thriller,\xa0Mystery', 'Release Date': '09/23/2022 ', 'Run Time': '1h 47m', 'Director': 'Andrew Hunt', 'URL': 'https://www.themoviedb.org/movie/916605'}, {'Name': 'Athena', 'Rating': '66', 'Genre': 'Drama,\xa0Action,\xa0Thriller', 'Release Da ...
# Secret Headquarters
# Ariel Schulman
# Henry Joost
# No director_name
# No director_name
# [{'Name': 'Terrifier 2', 'Rating': '74', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/28/2022 ', 'Run Time': '2h 18m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/663712'}, {'Name': 'Black Adam', 'Rating': '70', 'Genre': 'Action,\xa0Fantasy,\xa0Science Fiction', 'Release Date': '10/21/2022 ', 'Run Time': '2h 5m', 'Director': 'Jaume Collet-Serra', 'URL': 'https://www.themoviedb.org/movie/436270'}, {'Name': 'Jeepers Creepers: Reborn', 'Rating': '58', 'Genre': 'Horror,\xa0Thriller,\xa0Mystery', 'Release Date': '09/15/2022 ', 'Run Time': '1h 28m', 'Director': 'Timo Vuorensola', 'URL': 'https://www.themoviedb.org/movie/717728'}, {'Name': 'Fullmetal Alchemist: The Final Alchemy', 'Rating': '62', 'Genre': 'Action,\xa0Adventure,\xa0Fantasy', 'Release Date': '06/24/2022 ', 'Run Time': '2h 23m', 'Director': 'Fumihiko Sori', 'URL': 'https://www.themoviedb.org/movie/960704'}, {'Name': 'Orphan: First Kill', 'Rating': '68', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/17/2022 ', 'Run Time': '1h 39m', 'Director': 'William Brent Bell', 'URL': 'https://www.themoviedb.org/movie/760161'}, {'Name': 'Hocus Pocus 2', 'Rating': '76', 'Genre': 'Fantasy,\xa0Comedy,\xa0Family', 'Release Date': '09/30/2022 ', 'Run Time': '1h 47m', 'Director': 'Anne Fletcher', 'URL': 'https://www.themoviedb.org/movie/642885'}, {'Name': 'Fall', 'Rating': '74', 'Genre': 'Thriller', 'Release Date': '08/12/2022 ', 'Run Time': '1h 47m', 'Director': 'Scott Mann', 'URL': 'https://www.themoviedb.org/movie/985939'}, {'Name': 'Project Gemini', 'Rating': '56', 'Genre': 'Science Fiction', 'Release Date': '01/06/2022 ', 'Run Time': '1h 38m', 'Director': 'Serik Beyseu', 'URL': 'https://www.themoviedb.org/movie/575322'}, {'Name': 'Halloween Ends', 'Rating': '67', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/14/2022 ', 'Run Time': '1h 51m', 'Director': 'David Gordon Green', 'URL': 'https://www.themoviedb.org/movie/616820'}, {'Name': 'The Battle at Lake Changjin: Water Gate Bridge', 'Rating': '63', 'Genre': 'War,\xa0History,\xa0Action,\xa0Drama', 'Release Date': '02/01/2022 ', 'Run Time': '2h 29m', 'Director': 'Tsui Hark', 'URL': 'https://www.themoviedb.org/movie/928123'}, {'Name': 'Bullet Train', 'Rating': '75', 'Genre': 'Action,\xa0Comedy,\xa0Thriller', 'Release Date': '08/05/2022 ', 'Run Time': '2h 7m', 'Director': 'David Leitch', 'URL': 'https://www.themoviedb.org/movie/718930'}, {'Name': 'Piggy', 'Rating': '68', 'Genre': 'Drama,\xa0Thriller,\xa0Horror', 'Release Date': '10/14/2022 ', 'Run Time': '1h 40m', 'Director': 'Carlota Pereda', 'URL': 'https://www.themoviedb.org/movie/848058'}, {'Name': 'Crawlspace', 'Rating': '73', 'Genre': 'Thriller', 'Release Date': '03/31/2022 ', 'Run Time': '1h 30m', 'Director': 'L. Gustavo Cooper', 'URL': 'https://www.themoviedb.org/movie/879538'}, {'Name': 'The School for Good and Evil', 'Rating': '73', 'Genre': 'Fantasy,\xa0Action,\xa0Drama', 'Release Date': '10/19/2022 ', 'Run Time': '2h 26m', 'Director': 'Paul Feig', 'URL': 'https://www.themoviedb.org/movie/779782'}, {'Name': 'Coco', 'Rating': '82', 'Genre': 'Family,\xa0Animation,\xa0Fantasy,\xa0Music,\xa0Comedy,\xa0Adventure', 'Release Date': '11/24/2017 ', 'Run Time': '1h 45m', 'Director': 'Lee Unkrich', 'URL': 'https://www.themoviedb.org/movie/354912'}, {'Name': 'Terrifier', 'Rating': '65', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/15/2016 ', 'Run Time': '1h 24m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/420634'}, {'Name': 'Code Name Banshee', 'Rating': '48', 'Genre': 'Thriller,\xa0Action', 'Release Date': '07/14/2022 ', 'Run Time': '1h 33m', 'Director': 'Jon Keeyes', 'URL': 'https://www.themoviedb.org/movie/916719'}, {'Name': 'The Infernal Machine', 'Rating': '70', 'Genre': 'Thriller,\xa0Mystery', 'Release Date': '09/23/2022 ', 'Run Time': '1h 47m', 'Director': 'Andrew Hunt', 'URL': 'https://www.themoviedb.org/movie/916605'}, {'Name': 'Athena', 'Rating': '66', 'Genre': 'Drama,\xa0Action,\xa0Thriller', 'Release Da ...
# Pinocchio
# Robert Zemeckis
# No director_name
# ...
# Seoul Vibe
# Moon Hyun-sung
# No director_name
# [{'Name': 'Terrifier 2', 'Rating': '74', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/28/2022 ', 'Run Time': '2h 18m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/663712'}, {'Name': 'Black Adam', 'Rating': '70', 'Genre': 'Action,\xa0Fantasy,\xa0Science Fiction', 'Release Date': '10/21/2022 ', 'Run Time': '2h 5m', 'Director': 'Jaume Collet-Serra', 'URL': 'https://www.themoviedb.org/movie/436270'}, {'Name': 'Jeepers Creepers: Reborn', 'Rating': '58', 'Genre': 'Horror,\xa0Thriller,\xa0Mystery', 'Release Date': '09/15/2022 ', 'Run Time': '1h 28m', 'Director': 'Timo Vuorensola', 'URL': 'https://www.themoviedb.org/movie/717728'}, {'Name': 'Fullmetal Alchemist: The Final Alchemy', 'Rating': '62', 'Genre': 'Action,\xa0Adventure,\xa0Fantasy', 'Release Date': '06/24/2022 ', 'Run Time': '2h 23m', 'Director': 'Fumihiko Sori', 'URL': 'https://www.themoviedb.org/movie/960704'}, {'Name': 'Orphan: First Kill', 'Rating': '68', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/17/2022 ', 'Run Time': '1h 39m', 'Director': 'William Brent Bell', 'URL': 'https://www.themoviedb.org/movie/760161'}, {'Name': 'Hocus Pocus 2', 'Rating': '76', 'Genre': 'Fantasy,\xa0Comedy,\xa0Family', 'Release Date': '09/30/2022 ', 'Run Time': '1h 47m', 'Director': 'Anne Fletcher', 'URL': 'https://www.themoviedb.org/movie/642885'}, {'Name': 'Fall', 'Rating': '74', 'Genre': 'Thriller', 'Release Date': '08/12/2022 ', 'Run Time': '1h 47m', 'Director': 'Scott Mann', 'URL': 'https://www.themoviedb.org/movie/985939'}, {'Name': 'Project Gemini', 'Rating': '56', 'Genre': 'Science Fiction', 'Release Date': '01/06/2022 ', 'Run Time': '1h 38m', 'Director': 'Serik Beyseu', 'URL': 'https://www.themoviedb.org/movie/575322'}, {'Name': 'Halloween Ends', 'Rating': '67', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/14/2022 ', 'Run Time': '1h 51m', 'Director': 'David Gordon Green', 'URL': 'https://www.themoviedb.org/movie/616820'}, {'Name': 'The Battle at Lake Changjin: Water Gate Bridge', 'Rating': '63', 'Genre': 'War,\xa0History,\xa0Action,\xa0Drama', 'Release Date': '02/01/2022 ', 'Run Time': '2h 29m', 'Director': 'Tsui Hark', 'URL': 'https://www.themoviedb.org/movie/928123'}, {'Name': 'Bullet Train', 'Rating': '75', 'Genre': 'Action,\xa0Comedy,\xa0Thriller', 'Release Date': '08/05/2022 ', 'Run Time': '2h 7m', 'Director': 'David Leitch', 'URL': 'https://www.themoviedb.org/movie/718930'}, {'Name': 'Piggy', 'Rating': '68', 'Genre': 'Drama,\xa0Thriller,\xa0Horror', 'Release Date': '10/14/2022 ', 'Run Time': '1h 40m', 'Director': 'Carlota Pereda', 'URL': 'https://www.themoviedb.org/movie/848058'}, {'Name': 'Crawlspace', 'Rating': '73', 'Genre': 'Thriller', 'Release Date': '03/31/2022 ', 'Run Time': '1h 30m', 'Director': 'L. Gustavo Cooper', 'URL': 'https://www.themoviedb.org/movie/879538'}, {'Name': 'The School for Good and Evil', 'Rating': '73', 'Genre': 'Fantasy,\xa0Action,\xa0Drama', 'Release Date': '10/19/2022 ', 'Run Time': '2h 26m', 'Director': 'Paul Feig', 'URL': 'https://www.themoviedb.org/movie/779782'}, {'Name': 'Coco', 'Rating': '82', 'Genre': 'Family,\xa0Animation,\xa0Fantasy,\xa0Music,\xa0Comedy,\xa0Adventure', 'Release Date': '11/24/2017 ', 'Run Time': '1h 45m', 'Director': 'Lee Unkrich', 'URL': 'https://www.themoviedb.org/movie/354912'}, {'Name': 'Terrifier', 'Rating': '65', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/15/2016 ', 'Run Time': '1h 24m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/420634'}, {'Name': 'Code Name Banshee', 'Rating': '48', 'Genre': 'Thriller,\xa0Action', 'Release Date': '07/14/2022 ', 'Run Time': '1h 33m', 'Director': 'Jon Keeyes', 'URL': 'https://www.themoviedb.org/movie/916719'}, {'Name': 'The Infernal Machine', 'Rating': '70', 'Genre': 'Thriller,\xa0Mystery', 'Release Date': '09/23/2022 ', 'Run Time': '1h 47m', 'Director': 'Andrew Hunt', 'URL': 'https://www.themoviedb.org/movie/916605'}, {'Name': 'Athena', 'Rating': '66', 'Genre': 'Drama,\xa0Action,\xa0Thriller', 'Release Da ...
# It Chapter Two
# Andy Muschietti
# No director_name
# No director_name
# [{'Name': 'Terrifier 2', 'Rating': '74', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/28/2022 ', 'Run Time': '2h 18m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/663712'}, {'Name': 'Black Adam', 'Rating': '70', 'Genre': 'Action,\xa0Fantasy,\xa0Science Fiction', 'Release Date': '10/21/2022 ', 'Run Time': '2h 5m', 'Director': 'Jaume Collet-Serra', 'URL': 'https://www.themoviedb.org/movie/436270'}, {'Name': 'Jeepers Creepers: Reborn', 'Rating': '58', 'Genre': 'Horror,\xa0Thriller,\xa0Mystery', 'Release Date': '09/15/2022 ', 'Run Time': '1h 28m', 'Director': 'Timo Vuorensola', 'URL': 'https://www.themoviedb.org/movie/717728'}, {'Name': 'Fullmetal Alchemist: The Final Alchemy', 'Rating': '62', 'Genre': 'Action,\xa0Adventure,\xa0Fantasy', 'Release Date': '06/24/2022 ', 'Run Time': '2h 23m', 'Director': 'Fumihiko Sori', 'URL': 'https://www.themoviedb.org/movie/960704'}, {'Name': 'Orphan: First Kill', 'Rating': '68', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/17/2022 ', 'Run Time': '1h 39m', 'Director': 'William Brent Bell', 'URL': 'https://www.themoviedb.org/movie/760161'}, {'Name': 'Hocus Pocus 2', 'Rating': '76', 'Genre': 'Fantasy,\xa0Comedy,\xa0Family', 'Release Date': '09/30/2022 ', 'Run Time': '1h 47m', 'Director': 'Anne Fletcher', 'URL': 'https://www.themoviedb.org/movie/642885'}, {'Name': 'Fall', 'Rating': '74', 'Genre': 'Thriller', 'Release Date': '08/12/2022 ', 'Run Time': '1h 47m', 'Director': 'Scott Mann', 'URL': 'https://www.themoviedb.org/movie/985939'}, {'Name': 'Project Gemini', 'Rating': '56', 'Genre': 'Science Fiction', 'Release Date': '01/06/2022 ', 'Run Time': '1h 38m', 'Director': 'Serik Beyseu', 'URL': 'https://www.themoviedb.org/movie/575322'}, {'Name': 'Halloween Ends', 'Rating': '67', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/14/2022 ', 'Run Time': '1h 51m', 'Director': 'David Gordon Green', 'URL': 'https://www.themoviedb.org/movie/616820'}, {'Name': 'The Battle at Lake Changjin: Water Gate Bridge', 'Rating': '63', 'Genre': 'War,\xa0History,\xa0Action,\xa0Drama', 'Release Date': '02/01/2022 ', 'Run Time': '2h 29m', 'Director': 'Tsui Hark', 'URL': 'https://www.themoviedb.org/movie/928123'}, {'Name': 'Bullet Train', 'Rating': '75', 'Genre': 'Action,\xa0Comedy,\xa0Thriller', 'Release Date': '08/05/2022 ', 'Run Time': '2h 7m', 'Director': 'David Leitch', 'URL': 'https://www.themoviedb.org/movie/718930'}, {'Name': 'Piggy', 'Rating': '68', 'Genre': 'Drama,\xa0Thriller,\xa0Horror', 'Release Date': '10/14/2022 ', 'Run Time': '1h 40m', 'Director': 'Carlota Pereda', 'URL': 'https://www.themoviedb.org/movie/848058'}, {'Name': 'Crawlspace', 'Rating': '73', 'Genre': 'Thriller', 'Release Date': '03/31/2022 ', 'Run Time': '1h 30m', 'Director': 'L. Gustavo Cooper', 'URL': 'https://www.themoviedb.org/movie/879538'}, {'Name': 'The School for Good and Evil', 'Rating': '73', 'Genre': 'Fantasy,\xa0Action,\xa0Drama', 'Release Date': '10/19/2022 ', 'Run Time': '2h 26m', 'Director': 'Paul Feig', 'URL': 'https://www.themoviedb.org/movie/779782'}, {'Name': 'Coco', 'Rating': '82', 'Genre': 'Family,\xa0Animation,\xa0Fantasy,\xa0Music,\xa0Comedy,\xa0Adventure', 'Release Date': '11/24/2017 ', 'Run Time': '1h 45m', 'Director': 'Lee Unkrich', 'URL': 'https://www.themoviedb.org/movie/354912'}, {'Name': 'Terrifier', 'Rating': '65', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/15/2016 ', 'Run Time': '1h 24m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/420634'}, {'Name': 'Code Name Banshee', 'Rating': '48', 'Genre': 'Thriller,\xa0Action', 'Release Date': '07/14/2022 ', 'Run Time': '1h 33m', 'Director': 'Jon Keeyes', 'URL': 'https://www.themoviedb.org/movie/916719'}, {'Name': 'The Infernal Machine', 'Rating': '70', 'Genre': 'Thriller,\xa0Mystery', 'Release Date': '09/23/2022 ', 'Run Time': '1h 47m', 'Director': 'Andrew Hunt', 'URL': 'https://www.themoviedb.org/movie/916605'}, {'Name': 'Athena', 'Rating': '66', 'Genre': 'Drama,\xa0Action,\xa0Thriller', 'Release Da ...
# Fantastic Beasts: The Secrets of Dumbledore
# No director_name
# David Yates
# No director_name
# [{'Name': 'Terrifier 2', 'Rating': '74', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/28/2022 ', 'Run Time': '2h 18m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/663712'}, {'Name': 'Black Adam', 'Rating': '70', 'Genre': 'Action,\xa0Fantasy,\xa0Science Fiction', 'Release Date': '10/21/2022 ', 'Run Time': '2h 5m', 'Director': 'Jaume Collet-Serra', 'URL': 'https://www.themoviedb.org/movie/436270'}, {'Name': 'Jeepers Creepers: Reborn', 'Rating': '58', 'Genre': 'Horror,\xa0Thriller,\xa0Mystery', 'Release Date': '09/15/2022 ', 'Run Time': '1h 28m', 'Director': 'Timo Vuorensola', 'URL': 'https://www.themoviedb.org/movie/717728'}, {'Name': 'Fullmetal Alchemist: The Final Alchemy', 'Rating': '62', 'Genre': 'Action,\xa0Adventure,\xa0Fantasy', 'Release Date': '06/24/2022 ', 'Run Time': '2h 23m', 'Director': 'Fumihiko Sori', 'URL': 'https://www.themoviedb.org/movie/960704'}, {'Name': 'Orphan: First Kill', 'Rating': '68', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/17/2022 ', 'Run Time': '1h 39m', 'Director': 'William Brent Bell', 'URL': 'https://www.themoviedb.org/movie/760161'}, {'Name': 'Hocus Pocus 2', 'Rating': '76', 'Genre': 'Fantasy,\xa0Comedy,\xa0Family', 'Release Date': '09/30/2022 ', 'Run Time': '1h 47m', 'Director': 'Anne Fletcher', 'URL': 'https://www.themoviedb.org/movie/642885'}, {'Name': 'Fall', 'Rating': '74', 'Genre': 'Thriller', 'Release Date': '08/12/2022 ', 'Run Time': '1h 47m', 'Director': 'Scott Mann', 'URL': 'https://www.themoviedb.org/movie/985939'}, {'Name': 'Project Gemini', 'Rating': '56', 'Genre': 'Science Fiction', 'Release Date': '01/06/2022 ', 'Run Time': '1h 38m', 'Director': 'Serik Beyseu', 'URL': 'https://www.themoviedb.org/movie/575322'}, {'Name': 'Halloween Ends', 'Rating': '67', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/14/2022 ', 'Run Time': '1h 51m', 'Director': 'David Gordon Green', 'URL': 'https://www.themoviedb.org/movie/616820'}, {'Name': 'The Battle at Lake Changjin: Water Gate Bridge', 'Rating': '63', 'Genre': 'War,\xa0History,\xa0Action,\xa0Drama', 'Release Date': '02/01/2022 ', 'Run Time': '2h 29m', 'Director': 'Tsui Hark', 'URL': 'https://www.themoviedb.org/movie/928123'}, {'Name': 'Bullet Train', 'Rating': '75', 'Genre': 'Action,\xa0Comedy,\xa0Thriller', 'Release Date': '08/05/2022 ', 'Run Time': '2h 7m', 'Director': 'David Leitch', 'URL': 'https://www.themoviedb.org/movie/718930'}, {'Name': 'Piggy', 'Rating': '68', 'Genre': 'Drama,\xa0Thriller,\xa0Horror', 'Release Date': '10/14/2022 ', 'Run Time': '1h 40m', 'Director': 'Carlota Pereda', 'URL': 'https://www.themoviedb.org/movie/848058'}, {'Name': 'Crawlspace', 'Rating': '73', 'Genre': 'Thriller', 'Release Date': '03/31/2022 ', 'Run Time': '1h 30m', 'Director': 'L. Gustavo Cooper', 'URL': 'https://www.themoviedb.org/movie/879538'}, {'Name': 'The School for Good and Evil', 'Rating': '73', 'Genre': 'Fantasy,\xa0Action,\xa0Drama', 'Release Date': '10/19/2022 ', 'Run Time': '2h 26m', 'Director': 'Paul Feig', 'URL': 'https://www.themoviedb.org/movie/779782'}, {'Name': 'Coco', 'Rating': '82', 'Genre': 'Family,\xa0Animation,\xa0Fantasy,\xa0Music,\xa0Comedy,\xa0Adventure', 'Release Date': '11/24/2017 ', 'Run Time': '1h 45m', 'Director': 'Lee Unkrich', 'URL': 'https://www.themoviedb.org/movie/354912'}, {'Name': 'Terrifier', 'Rating': '65', 'Genre': 'Horror,\xa0Thriller', 'Release Date': '10/15/2016 ', 'Run Time': '1h 24m', 'Director': 'Damien Leone', 'URL': 'https://www.themoviedb.org/movie/420634'}, {'Name': 'Code Name Banshee', 'Rating': '48', 'Genre': 'Thriller,\xa0Action', 'Release Date': '07/14/2022 ', 'Run Time': '1h 33m', 'Director': 'Jon Keeyes', 'URL': 'https://www.themoviedb.org/movie/916719'}, {'Name': 'The Infernal Machine', 'Rating': '70', 'Genre': 'Thriller,\xa0Mystery', 'Release Date': '09/23/2022 ', 'Run Time': '1h 47m', 'Director': 'Andrew Hunt', 'URL': 'https://www.themoviedb.org/movie/916605'}, {'Name': 'Athena', 'Rating': '66', 'Genre': 'Drama,\xa0Action,\xa0Thriller', 'Release Da ...
# Avatar: The Way of Water
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [1], in <cell line: 15>()
#      46         release_date1 = release_date[:-4]
#      47 #         print(release_date1)                                  # Print to Fetch release_date1.
# ---> 49         run_time = soupdata_of_insidepage.find('span',class_='runtime').text.strip()
#      50 #         print(run_time)                                       # Print to Fetch run_time.
#      52         director_name = soupdata_of_insidepage.find('ol',class_='people no_image')
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
import pandas as pd    # Import pandas Librarie.

# %%
df = pd.DataFrame(all_page_urls)    # Createing DataFrame using panda.

# %%
df  # Print to get DF out put.
# Out:
#                                            Name Rating  \
# 0                                   Terrifier 2     74
# 1                                    Black Adam     70
# 2                      Jeepers Creepers: Reborn     58
# 3        Fullmetal Alchemist: The Final Alchemy     62
# 4                            Orphan: First Kill     68
# ..                                          ...    ...
# 78                                     V/H/S/99     58
# 79                                The Lost City     68
# 80                                   Seoul Vibe     69
# 81                               It Chapter Two     69
# 82  Fantastic Beasts: The Secrets of Dumbledore     68
#
#                                Genre Release Date Run Time  \
# 0                   Horror, Thriller  10/28/2022    2h 18m
# 1   Action, Fantasy, Science Fiction  10/21/2022     2h 5m
# 2          Horror, Thriller, Mystery  09/15/2022    1h 28m
# 3         Action, Adventure, Fantasy  06/24/2022    2h 23m
# 4                   Horror, Thriller  10/17/2022    1h 39m
# ..                               ...          ...      ...
# 78                  Horror, Thriller  10/20/2022    1h 39m
# 79         Action, Adventure, Comedy  03/25/2022    1h 52m
# 80  Action, Crime, Comedy, Adventure  08/26/2022    2h 20m
# 81                   Horror, Fantasy  09/06/2019    2h 50m
# 82        Fantasy, Adventure, Action  04/15/2022    2h 22m
#
#               Director                                       URL
# 0         Damien Leone   https://www.themoviedb.org/movie/663712
# 1   Jaume Collet-Serra   https://www.themoviedb.org/movie/436270
# 2      Timo Vuorensola   https://www.themoviedb.org/movie/717728
# 3        Fumihiko Sori   https://www.themoviedb.org/movie/960704
# 4   William Brent Bell   https://www.themoviedb.org/movie/760161
# ..                 ...                                       ...
# 78        Maggie Levin  https://www.themoviedb.org/movie/1005776
# 79           Aaron Nee   https://www.themoviedb.org/movie/752623
# 80      Moon Hyun-sung   https://www.themoviedb.org/movie/773867
# 81     Andy Muschietti   https://www.themoviedb.org/movie/474350
# 82         David Yates   https://www.themoviedb.org/movie/338953
#
# [83 rows x 7 columns]

# %%
df.to_excel('Movie-data.xlsx')    # Create all page info in excel.

# %%
pwd  # Used PWD to check the file location.

# %%
# import requests
# from bs4 import BeautifulSoup
# import re

# url = 'https://www.themoviedb.org'
# header={'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.51 Safari/537.36'}
# mylst = []

# for items in range(1,26):
#         # using loop to generate urls
#         number = str(items)
#         response = requests.get(url+'/movie?page='+number, headers = header).text
#         soupdata = BeautifulSoup(response)
#         divs = soupdata.find_all('div', class_='card style_1')

#         for items in divs:
#                 # using for loop to remove html code of all divs from a single page
#                 name = items.find('h2')  # extracting movie name
#                 link = name.find('a')['href']
#                 movie_name = items.find('h2').text  

#                 ans_url = url + link  # creating url which appears when we click on a movie                        

#                 inside_page_code = requests.get(ans_url,headers = header).text  # Extracting Runtime 
#                 soupdata_of_inpage = BeautifulSoup(inside_page_code,'lxml')  # Using conditional statements to extract 
#                                                                              # the runtime
#                 if soupdata_of_inpage.find('span',class_='runtime') == None:
#                     runtime = 'No data available'

#                 elif soupdata_of_inpage.find('span',class_='runtime') != None:
#                     runtime = soupdata_of_inpage.find('span',class_='runtime').text
#                 print(runtime)

#                 rating = soupdata_of_inpage.find('div',class_='percent')  # Extracting Rating of a movie 
#                                                                           # using Regular Expression
#                 c = rating.find('span')['class'][1]
#                 pattern = '\d+'
#                 final_rating = re.findall(pattern,c)
#                 Rating = ''
#                 for x in final_rating:
#                     Rating = int(x)

#                 release_date=soupdata_of_inpage.find('span',class_='release').text # Extracting release date 
#                                                                                    # using Regular expression       
#                 pattern1 = '\d+[/]\d+[/]\d+'
#                 final_release_date = re.findall(pattern1,release_date)
#                 for items in final_release_date:
#                     Release_Date=items

#                 genres=soupdata_of_inpage.find('span',class_='genres').text  # Extracting genres for a movie
#                 genres=genres.strip()

#                 direct_name = soupdata_of_inpage.find('ol',class_='people no_image')
#                 a = direct_name.find_all('li',class_='profile')  # Extracting Director Name using IF condition
#                 for items in a:
#                     b=items.find('p',class_='character').text
#                     if b.count('Director') == 1:
#                         director_name = items.find('a').text

#                 mydict = {}  # Creating a dictionary using all the above data
#                 mydict['Name'] = movie_name
#                 mydict['Rating'] = Rating
#                 mydict['Genre'] = genres
#                 mydict['Release date'] = Release_Date
#                 mydict['Runtime'] = runtime
#                 mydict['Director'] = director_name
#                 mydict['Url'] = ans_url

#                 mylst.append(mydict)  # Appending the dictionary in a list
        
# import pandas  as pd  # using pandas library to convert the data stored in a list into a tabular format
# l = pd.DataFrame(mylst)

# l.to_excel('movies_info.xlsx')  # using the above table and converting the data into a excelsheet
